# %% [markdown]
# # Verbesserung des Mensa Programms

# %% [markdown]
# ## Idee 1: Vormaitrier Text

# %% [markdown]
# !pip install tkhtmlview <br>
# !conda install tkhtmlview ?

# %% [markdown]
# Html Editor:<br>
# https://htmleditor.online/

# %% [markdown]
# Beispiel:

# %%
import tkinter as tk
from tkhtmlview import HTMLLabel

root = tk.Tk()
html_label = HTMLLabel(root, html='''<h1> Hello World </h1>''')
html_label.pack(fill="both", expand=True)
html_label.fit_height()
root.mainloop()

# %% [markdown]
# ## Idee 2: Ein Neuladen Knopf

# %% [markdown]
# #### Button - Widget

# %%
root = Tk()

myButton = Button(root, text='click Me!', command=funk)
myButton.pack() #function to show button in window

root.mainloop()

# %% [markdown]
# ## Idee 3: Verschiedene Einstellungen and tkinter verändern
# Z.b Fenster große: <br>
# https://pythonexamples.org/python-tkinter-set-window-size/ <br>
# Weitere Ideen Fenster Titel verändern:<br>
# https://www.pythontutorial.net/tkinter/tkinter-window/<br>
#
# ### + Sonstiges (werde selber Kreativ)

# %% [markdown]
# # An alle die Schon fertig sind
# Idee schreibe ein Skript was das intranet in singvolles und nicht teilt.

# %% [markdown]
# https://www.iwi.hs-karlsruhe.de/intranet/feed/rss/news.xml

# %%
# !pip install pip install beautifulsoup4

# %%
# !pip install lxml

# %%
import requests
from bs4 import BeautifulSoup
import lxml
#enter URL
url = "https://www.iwi.hs-karlsruhe.de/intranet/feed/rss/news.xml"

resp = requests.get(url)

soup = BeautifulSoup(resp.content, features="xml")

print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <rss version="2.0">
#  <channel>
#   <generator>
#    WII-Intranet
#   </generator>
#   <title>
#    WII-News
#   </title>
#   <description>
#    News aus dem Fachgebiet Wirtschaftsinformatik (IWI-WI)
#   </description>
#   <link>
#    https://www.iwi.hs-karlsruhe.de/intranet/feed/rss/
#   </link>
#   <language>
#    de-de
#   </language>
#   <pubDate>
#    Sun, 27 Nov 2022 23:00:00 +0100
#   </pubDate>
#   <item>
#    <title>
#     4. League of Legends Turnier der Fachschaft IWI
#    </title>
#    <link>
#     https://www.iwi.hs-karlsruhe.de/intranet?rss=02F2E9CB65DB27C694542161FA7F8AA7474CA525
#    </link>
#    <description>
# ...
